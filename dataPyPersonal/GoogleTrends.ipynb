# %%
import pickle
import pandas as pd
from pytrends.request import TrendReq
from matplotlib import rcParams
# %matplotlib inline
rcParams.update({'figure.autolayout': True})

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Defining the trends request
#   https://trends.google.com/trends/explore?q=blockchain&geo=US
kw_list = ["nintendo"]
pytrends = TrendReq(hl='en-US', tz=360)
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='')

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Interest Over Time
interest_over_time_df = pytrends.interest_over_time()
interest_over_time_df.head()
# Out:
#             nintendo isPartial
# date
# 2014-06-15        21     False
# 2014-06-22        20     False
# 2014-06-29        20     False
# 2014-07-06        21     False
# 2014-07-13        21     False

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# "Dumping" the dataframe to pkl
dataDumpPath = "./data/extracted/Trends/dataDump.pkl"
#interest_over_time_df.to_pickle(dataDumpPath)
interest_over_time_df = pd.read_pickle(dataDumpPath)
# interest_over_time_df.loc['2017-10-26']
print(interest_over_time_df.head())
interest_over_time_df["rmroman"].plot()
# Out:
#             rmroman isPartial
# date
# 2014-06-15        0     False
# 2014-06-22        0     False
# 2014-06-29        0     False
# 2014-07-06       36     False
# 2014-07-13        0     False

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Interest by Region
interest_by_region_df = pytrends.interest_by_region()
interest_by_region_df.sort_values(
    by=["nintendo"], ascending=False, inplace=True
)
interest_by_region_df.iloc[:20].plot.bar()
# fig = interest_by_region_df.iloc[:20].plot.bar()
# fig.get_figure().savefig('trends.png',dpi=500)

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Related Queries, returns a dictionary of dataframes
related_queries_dict = pytrends.related_queries()
print(related_queries_dict)
# Out:
# {'nintendo': {'top':                     query  value
# 0                  switch    100
# 1         switch nintendo     99
# 2            nintendo 3ds     31
# 3                     3ds     30
# 4          nintendo games     23
# 5                      ds     21
# 6             nintendo ds     20
# 7          super nintendo     20
# 8                     wii     14
# 9            nintendo wii     14
# 10                   game     13
# 11                  mario     12
# 12            nintendo 64     11
# 13  nintendo switch games     10
# 14           switch games     10
# 15                pokemon     10
# 16           new nintendo      9
# 17       nintendo classic      8
# 18           nes nintendo      7
# 19        nintendo 3ds xl      7
# 20                 3ds xl      7
# 21                    nes      6
# 22           nintendo 2ds      6
# 23          mini nintendo      6
# 24                    2ds      6, 'rising':                              query   value
# 0            nintendo switch games  132050
# 1                     switch games  129400
# 2                  switch nintendo   77300
# 3                           switch   74500
# 4         nintendo switch fortnite   62150
# 5       nintendo switch controller   55250
# 6     nintendo switch black friday   51200
# 7            nintendo switch price   49950
# 8                      nintendo nx   47300
# 9         nintendo switch gamestop   45700
# 10          nintendo switch amazon   44800
# 11              breath of the wild   43800
# 12          nintendo switch reddit   42300
# 13          nintendo switch bundle   39400
# 14         pokemon nintendo switch   37100
# 15      best nintendo switch games   36750
# 16          nintendo switch juegos   34600
# 17      nintendo switch mario kart   31600
# 18         walmart nintendo switch   31550
# 19            nintendo switch game   30600
# 20          nintendo switch online   30300
# 21        zelda breath of the wild   30200
# 22  nintendo switch pro controller   29800
# 23    nintendo switch release date   28950
# 24          target nintendo switch   28650}}

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Get Google Keyword Suggestions
suggestions_dict = pytrends.suggestions(keyword='nintendo')
print(suggestions_dict)
# Out:
# [{'mid': '/m/059wk', 'title': 'Nintendo', 'type': 'Consumer electronics company'}, {'mid': '/m/0130pygf', 'title': 'Nintendo Switch', 'type': 'Video game console'}, {'mid': '/m/07d5v', 'title': 'The Legend of Zelda', 'type': 'Video game series'}, {'mid': '/m/0bmjxs9', 'title': 'Nintendo 3DS', 'type': 'Game console'}, {'mid': '/m/028jm0', 'title': 'Nintendo DS', 'type': 'Game console'}]

# %%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Get Google Hot Trends data
trending_searches_df = pytrends.trending_searches()
print(trending_searches_df.head())
# Out:
#                        0
# 0  Australia vs Pakistan
# 1           Maren Morris
# 2            Nintendo E3
# 3            Jon Stewart
# 4          Banjo-Kazooie

# %%
# Get Google Top Charts
top_charts_df = pytrends.top_charts(2018, hl='en-US', tz=300, geo='GLOBAL' )
top_charts_df.head()
#print(top_charts_df.head())
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-60-0b85c9623bba> in <module>
#       1 # Get Google Top Charts
# ----> 2 top_charts_df = pytrends.top_charts(2018, hl='en-US', tz=300, geo='GLOBAL' )
#       3 top_charts_df.head()
#       4 #print(top_charts_df.head())
#
# ~/anaconda3/envs/NuevoCADI/lib/python3.7/site-packages/pytrends/request.py in top_charts(self, date, hl, tz, geo)
#     431             url=TrendReq.TOP_CHARTS_URL,
#     432             method=TrendReq.POST_METHOD,
# --> 433             params=chart_payload,
#     434         )['data']['entityList']
#     435         df = pd.DataFrame(req_json)
#
# ~/anaconda3/envs/NuevoCADI/lib/python3.7/site-packages/pytrends/request.py in _get_data(self, url, method, trim_chars, **kwargs)
#     142                 'The request failed: Google returned a '
#     143                 'response with code {0}.'.format(response.status_code),
# --> 144                 response=response)
#     145
#     146     def build_payload(self, kw_list, cat=0, timeframe='today 5-y', geo='',
#
# ResponseError: The request failed: Google returned a response with code 404.

# %%
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-40-d2907ecd25ad> in <module>
# ----> 1 top_charts_df = pytrends.top_charts(2018, hl='en-US', tz=300, geo='GLOBAL')
#       2 print(top_charts_df.head())
#
# ~/anaconda3/envs/NuevoCADI/lib/python3.7/site-packages/pytrends/request.py in top_charts(self, date, hl, tz, geo)
#     431             url=TrendReq.TOP_CHARTS_URL,
#     432             method=TrendReq.POST_METHOD,
# --> 433             params=chart_payload,
#     434         )['data']['entityList']
#     435         df = pd.DataFrame(req_json)
#
# ~/anaconda3/envs/NuevoCADI/lib/python3.7/site-packages/pytrends/request.py in _get_data(self, url, method, trim_chars, **kwargs)
#     142                 'The request failed: Google returned a '
#     143                 'response with code {0}.'.format(response.status_code),
# --> 144                 response=response)
#     145
#     146     def build_payload(self, kw_list, cat=0, timeframe='today 5-y', geo='',
#
# ResponseError: The request failed: Google returned a response with code 404.
