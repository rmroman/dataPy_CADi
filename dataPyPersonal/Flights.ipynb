# %%
# Import required libraries
import pandas as pd
import numpy as np

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Read data
flights = pd.read_csv("./data/Extracted/Flights/nycflights13.csv")
flights.shape
flights.tail()
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 336771  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336772  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336773  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336774  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336775  2013      9   30       NaN        NaN       NaN        NaN      MQ
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# 336771     NaN    3393    JFK  DCA       NaN       213   NaN     NaN
# 336772     NaN    3525    LGA  SYR       NaN       198   NaN     NaN
# 336773  N535MQ    3461    LGA  BNA       NaN       764   NaN     NaN
# 336774  N511MQ    3572    LGA  CLE       NaN       419   NaN     NaN
# 336775  N839MQ    3531    LGA  RDU       NaN       431   NaN     NaN

# %%
# Querying with specific constrains
flights.query("month == 1 & day == 1")
flights[(flights.month == 1) & (flights.day == 1)].head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     725    JFK  BQN     183.0      1576   5.0    44.0
# 4     461    LGA  ATL     116.0       762   5.0    54.0

# %%
# Querying by location
flights.iloc[2:9]
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 5  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
# 6  2013      1    1     555.0       -5.0     913.0       19.0      B6  N516JB
# 7  2013      1    1     557.0       -3.0     709.0      -14.0      EV  N829AS
# 8  2013      1    1     557.0       -3.0     838.0       -8.0      B6  N593JB
#
#    flight origin dest  air_time  distance  hour  minute
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     725    JFK  BQN     183.0      1576   5.0    44.0
# 4     461    LGA  ATL     116.0       762   5.0    54.0
# 5    1696    EWR  ORD     150.0       719   5.0    54.0
# 6     507    EWR  FLL     158.0      1065   5.0    55.0
# 7    5708    LGA  IAD      53.0       229   5.0    57.0
# 8      79    JFK  MCO     140.0       944   5.0    57.0

# %%
# Sort by key
flights.sort_values(['year', 'month', 'day'])
flights[['year', 'month', 'day']].head()
# Out:
#    year  month  day
# 0  2013      1    1
# 1  2013      1    1
# 2  2013      1    1
# 3  2013      1    1
# 4  2013      1    1

# %%
# Getting the unique elements in a column (categories)
flights.tailnum.unique()
flights[['origin', 'dest']].drop_duplicates().head()
# Out:
#   origin dest
# 0    EWR  IAH
# 1    LGA  IAH
# 2    JFK  MIA
# 3    JFK  BQN
# 4    LGA  ATL

# %%
# Adding categories
flights['gain'] = flights.arr_delay - flights.dep_delay
flights['speed'] = flights.distance / flights.air_time * 60

# %%
# Getting basic statistics
flights.dep_delay.mean()
# Out:
# 12.639070257304708

# %%
# Random sampling
selection = np.random.choice(flights.index, 10)
flights.loc[selection]
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 45290   2013     10   20    1725.0       -4.0    2024.0      -41.0      VX
# 219254  2013      5   28       NaN        NaN       NaN        NaN      US
# 7874    2013      1    9    2127.0       41.0    2358.0       40.0      EV
# 268875  2013      7   20    1516.0       17.0    1745.0       10.0      DL
# 322734  2013      9   15    2144.0       -1.0     122.0      -18.0      B6
# 283976  2013      8    5    1121.0       21.0    1354.0        5.0      DL
# 76071   2013     11   22    1628.0        3.0    1819.0       24.0      MQ
# 160650  2013      3   27     808.0       13.0    1020.0       -6.0      UA
# 332641  2013      9   26    1257.0       -3.0    1601.0        1.0      VX
# 294116  2013      8   15    1820.0        0.0    2106.0      -35.0      DL
#
#        tailnum  flight origin dest  air_time  distance  hour  minute  gain  \
# 45290   N521VA     193    EWR  SFO     332.0      2565  17.0    25.0 -37.0
# 219254     NaN    2167    LGA  DCA       NaN       214   NaN     NaN   NaN
# 7874    N11544    4645    EWR  JAX     124.0       820  21.0    27.0  -1.0
# 268875  N666DN     451    LGA  ATL     107.0       762  15.0    16.0  -7.0
# 322734  N708JB    1103    JFK  SJU     198.0      1598  21.0    44.0 -17.0
# 283976  N913DE     695    JFK  MCO     129.0       944  11.0    21.0 -16.0
# 76071   N530MQ    3748    EWR  ORD     129.0       719  16.0    28.0  21.0
# 160650  N589UA     561    LGA  DEN     212.0      1620   8.0     8.0 -19.0
# 332641  N634VA     411    JFK  LAX     334.0      2475  12.0    57.0   4.0
# 294116  N910DE      83    JFK  MIA     142.0      1089  18.0    20.0 -35.0
#
#              speed
# 45290   463.554217
# 219254         NaN
# 7874    396.774194
# 268875  427.289720
# 322734  484.242424
# 283976  439.069767
# 76071   334.418605
# 160650  458.490566
# 332641  444.610778
# 294116  460.140845

# %%
# Aggregated statistics
planes = flights.groupby("tailnum")
delay = planes.agg({
    "year": "count",
    "distance": "median",
    "arr_delay": "mean"
})
delay.query("year > 20 & distance < 2000").head()
# Out:
#          year  distance  arr_delay
# tailnum
# N0EGMQ    371     719.0   9.982955
# N10156    153     746.0  12.717241
# N102UW     48     541.0   2.937500
# N103US     46     529.0  -6.934783
# N104UW     47     529.0   1.804348

# %%
# Aggregated statistics
daily = flights.groupby(['year', 'month', 'day'])
per_day = daily['distance'].count()
per_month = per_day.groupby(level=['year', 'month']).sum()
(
    flights.groupby(['year', 'month', 'day'])
    [['arr_delay', 'dep_delay']]
    .mean()
    .query('arr_delay > 30 | dep_delay > 30')
).head()
# Out:
#                 arr_delay  dep_delay
# year month day
# 2013 1     16   34.247362  24.612865
#            31   32.602854  28.658363
#      2     11   36.290094  39.073598
#            27   31.252492  37.763274
#      3     8    85.862155  83.536921

# %% [markdown]
# Pie de página
